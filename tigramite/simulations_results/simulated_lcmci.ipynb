# %%
import numpy as np
from statsmodels.tsa.stattools import adfuller,kpss
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline     
import torch
import tigramite
from tigramite import data_processing as pp
from tigramite.toymodels import structural_causal_processes as toys
from tigramite import plotting as tp
from tigramite.lpcmci import LPCMCI
from tigramite.pcmci import PCMCI
from tigramite.independence_tests.parcorr import ParCorr
from statsmodels.tools.sm_exceptions import InterpolationWarning
import warnings
from tigramite.lpcmci import LPCMCI
import seaborn as sns
# from tigramite.independence_tests.gpdc import GPDC
from tigramite.independence_tests.cmiknn import CMIknn
from tigramite.independence_tests.rcot import RCOT
# from tigramite.independence_tests.cmisymb import CMIsymb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 20
#      18 # from tigramite.independence_tests.gpdc import GPDC
#      19 from tigramite.independence_tests.cmiknn import CMIknn
# ---> 20 from tigramite.independence_tests.rcot import RCOT
#      21 # from tigramite.independence_tests.cmisymb import CMIsymb
#
# ModuleNotFoundError: No module named 'tigramite.independence_tests.rcot'

# %%
import numpy as np
import pandas as pd

# Constants
num_samples = 306
time_steps_per_sample = 144
num_vars = 8
nan_rows_between_samples = 2

# Define the link assumptions
link_assumptions = {j: {(i, -tau): '' for i in range(num_vars) for tau in range(2) if (i, -tau) != (j, 0)}
                    for j in range(num_vars)}

link_assumptions[0][(1, 0)] = '<?-'  # Example: Var1 (Nd) depends on Var2 (P)
link_assumptions[1][(0, 0)] = '-?>'
link_assumptions[7][(1, 0)] = '<?-'  # Example: Var8 (CF) depends on Var2 (P)
link_assumptions[1][(7, 0)] = '-?>'
link_assumptions[0][(0, -1)] = '-?>' # Var1 (Nd) depends on its own lag
link_assumptions[0][(1, -1)] = '-?>' # Var1 (Nd) depends on Var2 (P) lag
link_assumptions[7][(1, -1)] = '-?>' # Var8 (CF) depends on Var2 (P) lag

link_assumptions[7][(0, -1)] = 'o?>' # Var8 (CF) depends on Var1 (Nd) lag
link_assumptions[1][(0, -1)] = 'o?>' # Var2 (P) depends on Var1 (Nd) lag
link_assumptions[1][(7, -1)] = 'o?>' # Var2 (P) depends on Var8 (CF) lag
link_assumptions[7][(7, -1)] = 'o?>' # Var8 (CF) depends on its own lag

for j in range(2, 7):
    link_assumptions[j][(0, 0)] = '<?-'  # Var3 to Var7 (meteorological) depend on Var1 (Nd)
    link_assumptions[0][(j, 0)] = '-?>'
    link_assumptions[j][(7, 0)] = '<?-'  # Var3 to Var7 (meteorological) depend on Var8 (CF)
    link_assumptions[7][(j, 0)] = '-?>'

# Function to apply dependencies based on link assumptions
def apply_dependencies(sample, link_assumptions):
    for j in range(num_vars):
        for (i, lag), dependency in link_assumptions[j].items():
            if dependency == '<?-':  # i influences j at lag 0
                sample[:, j] += 0.5 * np.tanh(sample[:, i])
            elif dependency == '-?>':  # j influences i at lag 0
                sample[:, i] += 0.3 * np.tanh(sample[:, j])
            elif dependency == 'o?>':  # lagged influence
                for t in range(-lag, time_steps_per_sample):
                    sample[t, j] += 0.2 * np.tanh(sample[t + lag, i])
    return sample

# Generate stationary time series data
def generate_stationary_sample():
    np.random.seed(42)  # For reproducibility
    
    # Use random walks (differences of random walks are stationary)
    sample = np.cumsum(np.random.randn(time_steps_per_sample, num_vars), axis=0)
    
    sample = apply_dependencies(sample, link_assumptions)
    
    # Differencing to ensure stationarity
    sample = np.diff(sample, axis=0)
    
    return sample

# Create all samples with NaN rows in between
all_samples = []
for _ in range(num_samples):
    sample = generate_stationary_sample()
    all_samples.append(sample)
    # Add NaN rows between samples
    all_samples.append(np.full((nan_rows_between_samples, num_vars), np.nan))

# Combine into a single DataFrame
data = np.vstack(all_samples)
df = pd.DataFrame(data, columns=[f"Var{i+1}" for i in range(num_vars)])

print(df)
# Out:
#            Var1      Var2      Var3      Var4      Var5      Var6      Var7  \
# 0     -0.211511  0.686494 -0.789091 -0.791403 -0.083711 -2.238953 -2.050591
# 1     -1.123877 -0.440372 -2.628680 -3.132960 -0.255008 -1.946433 -1.653128
# 2     -0.545733  0.008600 -0.226612  1.300080  0.323743  0.632688  0.322675
# 3     -0.761197 -0.961258  0.592902 -1.450487 -0.020780 -2.189313 -1.557829
# 4      0.953858  0.390902  0.403732  0.218276 -0.959142 -0.200464  0.058741
# ...         ...       ...       ...       ...       ...       ...       ...
# 44365 -0.064140  0.297303  0.534681  0.635245  1.827035  0.666858 -0.030833
# 44366  1.189485 -1.154137  0.607193  0.710966 -0.287771  1.385500 -0.140263
# 44367 -0.173072 -0.197275 -1.984318 -2.328094  0.706462 -1.735004 -1.879435
# 44368       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 44369       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#            Var8
# 0      0.118094
# 1     -1.467715
# 2      1.226123
# 3     -0.318025
# 4      1.108705
# ...         ...
# 44365  0.950519
# 44366  0.140728
# 44367 -2.152709
# 44368       NaN
# 44369       NaN
#
# [44370 rows x 8 columns]

# %%
dat = df.values

# empty list to store the modified columns to separate trajectories
modified_columns = []

for col in range(dat.shape[1]):
    column_data = dat[:, col]
    
    # append the modified column to the list
    modified_columns.append(column_data)

modified_data = np.column_stack(modified_columns)

dat = modified_data # handle missingness
n_a_n = np.isnan(dat).any(axis=1)
dat[n_a_n] = 999
#dat = dat[0:150,:]

# initialize dataframe object, specify variable names
var_names = ['Nd','Pr','sst','lts','fth','ws','div','cf']
dataframe = pp.DataFrame(dat, var_names=var_names, missing_flag = 999)
tp.plot_timeseries(dataframe); plt.show()

# %%
cmi_knn = CMIknn(significance='fixed_thres', model_selection_folds=3)
lpcmci_loc = LPCMCI(
    dataframe=dataframe, 
    cond_ind_test=cmi_knn,
    verbosity=1)
results = lpcmci_loc.run_lpcmci(tau_max=2, pc_alpha=.05)#, link_assumptions = link_assumptions)
tp.plot_time_series_graph(graph=results['graph'],
                          val_matrix=results['val_matrix'], save_name = "parcorr_simulated_nolinkass.png")

'''
graph : array of shape (N, N, tau_max+1)
            Resulting DPAG, representing the learned causal relationships.
        val_matrix : array of shape (N, N, tau_max+1)
            Estimated matrix of test statistic values regarding adjacencies.
        p_matrix : array of shape [N, N, tau_max+1]
            Estimated matrix of p-values regarding adjacencies.
'''
# Out:
# =======================================================
# =======================================================
# Starting preliminary phase  1
#
# Starting test phase
#
# p = 0
# (0,-2) independent (0, 0) given () union set()
# (0,-1) independent (0, 0) given () union set()
# (1,-2) independent (1, 0) given () union set()
# (1,-1) independent (1, 0) given () union set()
# (2,-2) independent (2, 0) given () union set()
# (2,-1) independent (2, 0) given () union set()
# (3,-2) independent (3, 0) given () union set()
# (3,-1) independent (3, 0) given () union set()
# (4,-2) independent (4, 0) given () union set()
# (4,-1) independent (4, 0) given () union set()
# (5,-2) independent (5, 0) given () union set()
# (5,-1) independent (5, 0) given () union set()
# (6,-2) independent (6, 0) given () union set()
# (6,-1) independent (6, 0) given () union set()
# (7,-2) independent (7, 0) given () union set()
# (7,-1) independent (7, 0) given () union set()
# Writing:   (0,-2) oL> (0, 0) ==> (0,-2)     (0, 0)
# Writing:   (0,-1) oL> (0, 0) ==> (0,-1)     (0, 0)
# Writing:   (1,-2) oL> (1, 0) ==> (1,-2)     (1, 0)
# Writing:   (1,-1) oL> (1, 0) ==> (1,-1)     (1, 0)
# Writing:   (2,-2) oL> (2, 0) ==> (2,-2)     (2, 0)
# Writing:   (2,-1) oL> (2, 0) ==> (2,-1)     (2, 0)
# Writing:   (3,-2) oL> (3, 0) ==> (3,-2)     (3, 0)
# Writing:   (3,-1) oL> (3, 0) ==> (3,-1)     (3, 0)
# Writing:   (4,-2) oL> (4, 0) ==> (4,-2)     (4, 0)
# Writing:   (4,-1) oL> (4, 0) ==> (4,-1)     (4, 0)
# Writing:   (5,-2) oL> (5, 0) ==> (5,-2)     (5, 0)
# Writing:   (5,-1) oL> (5, 0) ==> (5,-1)     (5, 0)
# Writing:   (6,-2) oL> (6, 0) ==> (6,-2)     (6, 0)
# Writing:   (6,-1) oL> (6, 0) ==> (6,-1)     (6, 0)
# Writing:   (7,-2) oL> (7, 0) ==> (7,-2)     (7, 0)
# Writing:   (7,-1) oL> (7, 0) ==> (7,-1)     (7, 0)
# (0, 0) independent (1, 0) given () union set()
# (0, 0) independent (1, 0) given () union set()
# (0, 0) independent (2, 0) given () union set()
# (0, 0) independent (2, 0) given () union set()
# (0, 0) independent (3, 0) given () union set()
# (0, 0) independent (3, 0) given () union set()
# (0, 0) independent (4, 0) given () union set()
# (0, 0) independent (4, 0) given () union set()
# (0, 0) independent (5, 0) given () union set()
# (0, 0) independent (5, 0) given () union set()
# (0, 0) independent (6, 0) given () union set()
# (0, 0) independent (6, 0) given () union set()
# (0, 0) independent (7, 0) given () union set()
# (0, 0) independent (7, 0) given () union set()
# (1, 0) independent (2, 0) given () union set()
# (1, 0) independent (2, 0) given () union set()
# (1, 0) independent (3, 0) given () union set()
# (1, 0) independent (3, 0) given () union set()
# (1, 0) independent (4, 0) given () union set()
# (1, 0) independent (4, 0) given () union set()
# (1, 0) independent (5, 0) given () union set()
# (1, 0) independent (5, 0) given () union set()
# (1, 0) independent (6, 0) given () union set()
# (1, 0) independent (6, 0) given () union set()
# (2, 0) independent (3, 0) given () union set()
# (2, 0) independent (3, 0) given () union set()
# (2, 0) independent (4, 0) given () union set()
# (2, 0) independent (4, 0) given () union set()
# (2, 0) independent (5, 0) given () union set()
# (2, 0) independent (5, 0) given () union set()
# (2, 0) independent (6, 0) given () union set()
# (2, 0) independent (6, 0) given () union set()
# (2, 0) independent (7, 0) given () union set()
# (2, 0) independent (7, 0) given () union set()
# (3, 0) independent (4, 0) given () union set()
# (3, 0) independent (4, 0) given () union set()
# (3, 0) independent (5, 0) given () union set()
# (3, 0) independent (5, 0) given () union set()
# (3, 0) independent (6, 0) given () union set()
# (3, 0) independent (6, 0) given () union set()
# (3, 0) independent (7, 0) given () union set()
# (3, 0) independent (7, 0) given () union set()
# (4, 0) independent (5, 0) given () union set()
# (4, 0) independent (5, 0) given () union set()
# (4, 0) independent (6, 0) given () union set()
# (4, 0) independent (6, 0) given () union set()
# (5, 0) independent (6, 0) given () union set()
# (5, 0) independent (6, 0) given () union set()
# (5, 0) independent (7, 0) given () union set()
# (5, 0) independent (7, 0) given () union set()
# (6, 0) independent (7, 0) given () union set()
# (6, 0) independent (7, 0) given () union set()
# Writing:   (0, 0) o?o (1, 0) ==> (0, 0)     (1, 0)
# Writing:   (1, 0) o?o (0, 0) ==> (1, 0)     (0, 0)
# Writing:   (0, 0) o?o (2, 0) ==> (0, 0)     (2, 0)
# Writing:   (2, 0) o?o (0, 0) ==> (2, 0)     (0, 0)
# Writing:   (1, 0) o?o (2, 0) ==> (1, 0)     (2, 0)
# Writing:   (2, 0) o?o (1, 0) ==> (2, 0)     (1, 0)
# Writing:   (0, 0) o?o (3, 0) ==> (0, 0)     (3, 0)
# Writing:   (3, 0) o?o (0, 0) ==> (3, 0)     (0, 0)
# Writing:   (1, 0) o?o (3, 0) ==> (1, 0)     (3, 0)
# Writing:   (3, 0) o?o (1, 0) ==> (3, 0)     (1, 0)
# Writing:   (2, 0) o?o (3, 0) ==> (2, 0)     (3, 0)
# Writing:   (3, 0) o?o (2, 0) ==> (3, 0)     (2, 0)
# Writing:   (0, 0) o?o (4, 0) ==> (0, 0)     (4, 0)
# Writing:   (4, 0) o?o (0, 0) ==> (4, 0)     (0, 0)
# Writing:   (1, 0) o?o (4, 0) ==> (1, 0)     (4, 0)
# Writing:   (4, 0) o?o (1, 0) ==> (4, 0)     (1, 0)
# Writing:   (2, 0) o?o (4, 0) ==> (2, 0)     (4, 0)
# Writing:   (4, 0) o?o (2, 0) ==> (4, 0)     (2, 0)
# Writing:   (3, 0) o?o (4, 0) ==> (3, 0)     (4, 0)
# Writing:   (4, 0) o?o (3, 0) ==> (4, 0)     (3, 0)
# Writing:   (0, 0) o?o (5, 0) ==> (0, 0)     (5, 0)
# Writing:   (5, 0) o?o (0, 0) ==> (5, 0)     (0, 0)
# Writing:   (1, 0) o?o (5, 0) ==> (1, 0)     (5, 0)
# Writing:   (5, 0) o?o (1, 0) ==> (5, 0)     (1, 0)
# Writing:   (2, 0) o?o (5, 0) ==> (2, 0)     (5, 0)
# Writing:   (5, 0) o?o (2, 0) ==> (5, 0)     (2, 0)
# Writing:   (3, 0) o?o (5, 0) ==> (3, 0)     (5, 0)
# Writing:   (5, 0) o?o (3, 0) ==> (5, 0)     (3, 0)
# Writing:   (4, 0) o?o (5, 0) ==> (4, 0)     (5, 0)
# Writing:   (5, 0) o?o (4, 0) ==> (5, 0)     (4, 0)
# Writing:   (0, 0) o?o (6, 0) ==> (0, 0)     (6, 0)
# Writing:   (6, 0) o?o (0, 0) ==> (6, 0)     (0, 0)
# Writing:   (1, 0) o?o (6, 0) ==> (1, 0)     (6, 0)
# Writing:   (6, 0) o?o (1, 0) ==> (6, 0)     (1, 0)
# Writing:   (2, 0) o?o (6, 0) ==> (2, 0)     (6, 0)
# Writing:   (6, 0) o?o (2, 0) ==> (6, 0)     (2, 0)
# Writing:   (3, 0) o?o (6, 0) ==> (3, 0)     (6, 0)
# Writing:   (6, 0) o?o (3, 0) ==> (6, 0)     (3, 0)
# Writing:   (4, 0) o?o (6, 0) ==> (4, 0)     (6, 0)
# Writing:   (6, 0) o?o (4, 0) ==> (6, 0)     (4, 0)
# Writing:   (5, 0) o?o (6, 0) ==> (5, 0)     (6, 0)
# Writing:   (6, 0) o?o (5, 0) ==> (6, 0)     (5, 0)
# Writing:   (0, 0) o?o (7, 0) ==> (0, 0)     (7, 0)
# Writing:   (7, 0) o?o (0, 0) ==> (7, 0)     (0, 0)
# Writing:   (2, 0) o?o (7, 0) ==> (2, 0)     (7, 0)
# Writing:   (7, 0) o?o (2, 0) ==> (7, 0)     (2, 0)
# Writing:   (3, 0) o?o (7, 0) ==> (3, 0)     (7, 0)
# Writing:   (7, 0) o?o (3, 0) ==> (7, 0)     (3, 0)
# Writing:   (5, 0) o?o (7, 0) ==> (5, 0)     (7, 0)
# Writing:   (7, 0) o?o (5, 0) ==> (7, 0)     (5, 0)
# Writing:   (6, 0) o?o (7, 0) ==> (6, 0)     (7, 0)
# Writing:   (7, 0) o?o (6, 0) ==> (7, 0)     (6, 0)
# (0,-1) independent (1, 0) given () union set()
# (0,-1) independent (2, 0) given () union set()
# (0,-1) independent (3, 0) given () union set()
# (0,-1) independent (4, 0) given () union set()
# (0,-1) independent (5, 0) given () union set()
# (0,-1) independent (6, 0) given () union set()
# (0,-1) independent (7, 0) given () union set()
# (1,-1) independent (0, 0) given () union set()
# (1,-1) independent (2, 0) given () union set()
# (1,-1) independent (3, 0) given () union set()
# (1,-1) independent (4, 0) given () union set()
# (1,-1) independent (5, 0) given () union set()
# (1,-1) independent (6, 0) given () union set()
# (1,-1) independent (7, 0) given () union set()
# (2,-1) independent (0, 0) given () union set()
# (2,-1) independent (1, 0) given () union set()
# (2,-1) independent (3, 0) given () union set()
# (2,-1) independent (4, 0) given () union set()
# (2,-1) independent (5, 0) given () union set()
# (2,-1) independent (6, 0) given () union set()
# (2,-1) independent (7, 0) given () union set()
# (3,-1) independent (0, 0) given () union set()
# (3,-1) independent (1, 0) given () union set()
# (3,-1) independent (2, 0) given () union set()
# (3,-1) independent (4, 0) given () union set()
# (3,-1) independent (5, 0) given () union set()
# (3,-1) independent (6, 0) given () union set()
# (3,-1) independent (7, 0) given () union set()
# (4,-1) independent (0, 0) given () union set()
# (4,-1) independent (1, 0) given () union set()
# (4,-1) independent (2, 0) given () union set()
# (4,-1) independent (3, 0) given () union set()
# (4,-1) independent (5, 0) given () union set()
# (4,-1) independent (6, 0) given () union set()
# (4,-1) independent (7, 0) given () union set()
# (5,-1) independent (0, 0) given () union set()
# (5,-1) independent (1, 0) given () union set()
# (5,-1) independent (2, 0) given () union set()
# (5,-1) independent (3, 0) given () union set()
# (5,-1) independent (4, 0) given () union set()
# (5,-1) independent (6, 0) given () union set()
# (5,-1) independent (7, 0) given () union set()
# (6,-1) independent (0, 0) given () union set()
# (6,-1) independent (1, 0) given () union set()
# (6,-1) independent (2, 0) given () union set()
# (6,-1) independent (3, 0) given () union set()
# (6,-1) independent (4, 0) given () union set()
# (6,-1) independent (5, 0) given () union set()
# (6,-1) independent (7, 0) given () union set()
# (7,-1) independent (0, 0) given () union set()
# (7,-1) independent (1, 0) given () union set()
# (7,-1) independent (2, 0) given () union set()
# (7,-1) independent (3, 0) given () union set()
# (7,-1) independent (4, 0) given () union set()
# (7,-1) independent (5, 0) given () union set()
# (7,-1) independent (6, 0) given () union set()
# Writing:   (1,-1) oL> (0, 0) ==> (1,-1)     (0, 0)
# Writing:   (2,-1) oL> (0, 0) ==> (2,-1)     (0, 0)
# Writing:   (3,-1) oL> (0, 0) ==> (3,-1)     (0, 0)
# Writing:   (4,-1) oL> (0, 0) ==> (4,-1)     (0, 0)
# Writing:   (5,-1) oL> (0, 0) ==> (5,-1)     (0, 0)
# Writing:   (6,-1) oL> (0, 0) ==> (6,-1)     (0, 0)
# Writing:   (7,-1) oL> (0, 0) ==> (7,-1)     (0, 0)
# Writing:   (0,-1) oL> (1, 0) ==> (0,-1)     (1, 0)
# Writing:   (2,-1) oL> (1, 0) ==> (2,-1)     (1, 0)
# Writing:   (3,-1) oL> (1, 0) ==> (3,-1)     (1, 0)
# Writing:   (4,-1) oL> (1, 0) ==> (4,-1)     (1, 0)
# Writing:   (5,-1) oL> (1, 0) ==> (5,-1)     (1, 0)
# Writing:   (6,-1) oL> (1, 0) ==> (6,-1)     (1, 0)
# Writing:   (7,-1) oL> (1, 0) ==> (7,-1)     (1, 0)
# Writing:   (0,-1) oL> (2, 0) ==> (0,-1)     (2, 0)
# Writing:   (1,-1) oL> (2, 0) ==> (1,-1)     (2, 0)
# Writing:   (3,-1) oL> (2, 0) ==> (3,-1)     (2, 0)
# Writing:   (4,-1) oL> (2, 0) ==> (4,-1)     (2, 0)
# Writing:   (5,-1) oL> (2, 0) ==> (5,-1)     (2, 0)
# Writing:   (6,-1) oL> (2, 0) ==> (6,-1)     (2, 0)
# Writing:   (7,-1) oL> (2, 0) ==> (7,-1)     (2, 0)
# Writing:   (0,-1) oL> (3, 0) ==> (0,-1)     (3, 0)
# Writing:   (1,-1) oL> (3, 0) ==> (1,-1)     (3, 0)
# Writing:   (2,-1) oL> (3, 0) ==> (2,-1)     (3, 0)
# Writing:   (4,-1) oL> (3, 0) ==> (4,-1)     (3, 0)
# Writing:   (5,-1) oL> (3, 0) ==> (5,-1)     (3, 0)
# Writing:   (6,-1) oL> (3, 0) ==> (6,-1)     (3, 0)
# Writing:   (7,-1) oL> (3, 0) ==> (7,-1)     (3, 0)
# Writing:   (0,-1) oL> (4, 0) ==> (0,-1)     (4, 0)
# Writing:   (1,-1) oL> (4, 0) ==> (1,-1)     (4, 0)
# Writing:   (2,-1) oL> (4, 0) ==> (2,-1)     (4, 0)
# Writing:   (3,-1) oL> (4, 0) ==> (3,-1)     (4, 0)
# Writing:   (5,-1) oL> (4, 0) ==> (5,-1)     (4, 0)
# Writing:   (6,-1) oL> (4, 0) ==> (6,-1)     (4, 0)
# Writing:   (7,-1) oL> (4, 0) ==> (7,-1)     (4, 0)
# Writing:   (0,-1) oL> (5, 0) ==> (0,-1)     (5, 0)
# Writing:   (1,-1) oL> (5, 0) ==> (1,-1)     (5, 0)
# Writing:   (2,-1) oL> (5, 0) ==> (2,-1)     (5, 0)
# Writing:   (3,-1) oL> (5, 0) ==> (3,-1)     (5, 0)
# Writing:   (4,-1) oL> (5, 0) ==> (4,-1)     (5, 0)
# Writing:   (6,-1) oL> (5, 0) ==> (6,-1)     (5, 0)
# Writing:   (7,-1) oL> (5, 0) ==> (7,-1)     (5, 0)
# Writing:   (0,-1) oL> (6, 0) ==> (0,-1)     (6, 0)
# Writing:   (1,-1) oL> (6, 0) ==> (1,-1)     (6, 0)
# Writing:   (2,-1) oL> (6, 0) ==> (2,-1)     (6, 0)
# Writing:   (3,-1) oL> (6, 0) ==> (3,-1)     (6, 0)
# Writing:   (4,-1) oL> (6, 0) ==> (4,-1)     (6, 0)
# Writing:   (5,-1) oL> (6, 0) ==> (5,-1)     (6, 0)
# Writing:   (7,-1) oL> (6, 0) ==> (7,-1)     (6, 0)
# Writing:   (0,-1) oL> (7, 0) ==> (0,-1)     (7, 0)
# Writing:   (1,-1) oL> (7, 0) ==> (1,-1)     (7, 0)
# Writing:   (2,-1) oL> (7, 0) ==> (2,-1)     (7, 0)
# Writing:   (3,-1) oL> (7, 0) ==> (3,-1)     (7, 0)
# Writing:   (4,-1) oL> (7, 0) ==> (4,-1)     (7, 0)
# Writing:   (5,-1) oL> (7, 0) ==> (5,-1)     (7, 0)
# Writing:   (6,-1) oL> (7, 0) ==> (6,-1)     (7, 0)
# (0,-2) independent (1, 0) given () union set()
# (0,-2) independent (2, 0) given () union set()
# (0,-2) independent (3, 0) given () union set()
# (0,-2) independent (4, 0) given () union set()
# (0,-2) independent (5, 0) given () union set()
# (0,-2) independent (6, 0) given () union set()
# (0,-2) independent (7, 0) given () union set()
# (1,-2) independent (0, 0) given () union set()
# (1,-2) independent (2, 0) given () union set()
# (1,-2) independent (3, 0) given () union set()
# (1,-2) independent (4, 0) given () union set()
# (1,-2) independent (5, 0) given () union set()
# (1,-2) independent (6, 0) given () union set()
# (1,-2) independent (7, 0) given () union set()
# (2,-2) independent (0, 0) given () union set()
# (2,-2) independent (1, 0) given () union set()
# (2,-2) independent (3, 0) given () union set()
# (2,-2) independent (4, 0) given () union set()
# (2,-2) independent (5, 0) given () union set()
# (2,-2) independent (6, 0) given () union set()
# (2,-2) independent (7, 0) given () union set()
# (3,-2) independent (0, 0) given () union set()
# (3,-2) independent (1, 0) given () union set()
# (3,-2) independent (2, 0) given () union set()
# (3,-2) independent (4, 0) given () union set()
# (3,-2) independent (5, 0) given () union set()
# (3,-2) independent (6, 0) given () union set()
# (3,-2) independent (7, 0) given () union set()
# (4,-2) independent (0, 0) given () union set()
# (4,-2) independent (1, 0) given () union set()
# (4,-2) independent (2, 0) given () union set()
# (4,-2) independent (3, 0) given () union set()
# (4,-2) independent (5, 0) given () union set()
# (4,-2) independent (6, 0) given () union set()
# (4,-2) independent (7, 0) given () union set()
# (5,-2) independent (0, 0) given () union set()
# (5,-2) independent (1, 0) given () union set()
# (5,-2) independent (2, 0) given () union set()
# (5,-2) independent (3, 0) given () union set()
# (5,-2) independent (6, 0) given () union set()
# (5,-2) independent (7, 0) given () union set()
# (6,-2) independent (1, 0) given () union set()
# (6,-2) independent (2, 0) given () union set()
# (6,-2) independent (3, 0) given () union set()
# (6,-2) independent (4, 0) given () union set()
# (6,-2) independent (5, 0) given () union set()
# (6,-2) independent (7, 0) given () union set()
# (7,-2) independent (0, 0) given () union set()
# (7,-2) independent (1, 0) given () union set()
# (7,-2) independent (2, 0) given () union set()
# (7,-2) independent (3, 0) given () union set()
# (7,-2) independent (4, 0) given () union set()
# (7,-2) independent (5, 0) given () union set()
# (7,-2) independent (6, 0) given () union set()
# Writing:   (1,-2) oL> (0, 0) ==> (1,-2)     (0, 0)
# Writing:   (2,-2) oL> (0, 0) ==> (2,-2)     (0, 0)
# Writing:   (3,-2) oL> (0, 0) ==> (3,-2)     (0, 0)
# Writing:   (4,-2) oL> (0, 0) ==> (4,-2)     (0, 0)
# Writing:   (5,-2) oL> (0, 0) ==> (5,-2)     (0, 0)
# Writing:   (7,-2) oL> (0, 0) ==> (7,-2)     (0, 0)
# Writing:   (0,-2) oL> (1, 0) ==> (0,-2)     (1, 0)
# Writing:   (2,-2) oL> (1, 0) ==> (2,-2)     (1, 0)
# Writing:   (3,-2) oL> (1, 0) ==> (3,-2)     (1, 0)
# Writing:   (4,-2) oL> (1, 0) ==> (4,-2)     (1, 0)
# Writing:   (5,-2) oL> (1, 0) ==> (5,-2)     (1, 0)
# Writing:   (6,-2) oL> (1, 0) ==> (6,-2)     (1, 0)
# Writing:   (7,-2) oL> (1, 0) ==> (7,-2)     (1, 0)
# Writing:   (0,-2) oL> (2, 0) ==> (0,-2)     (2, 0)
# Writing:   (1,-2) oL> (2, 0) ==> (1,-2)     (2, 0)
# Writing:   (3,-2) oL> (2, 0) ==> (3,-2)     (2, 0)
# Writing:   (4,-2) oL> (2, 0) ==> (4,-2)     (2, 0)
# Writing:   (5,-2) oL> (2, 0) ==> (5,-2)     (2, 0)
# Writing:   (6,-2) oL> (2, 0) ==> (6,-2)     (2, 0)
# Writing:   (7,-2) oL> (2, 0) ==> (7,-2)     (2, 0)
# Writing:   (0,-2) oL> (3, 0) ==> (0,-2)     (3, 0)
# Writing:   (1,-2) oL> (3, 0) ==> (1,-2)     (3, 0)
# Writing:   (2,-2) oL> (3, 0) ==> (2,-2)     (3, 0)
# Writing:   (4,-2) oL> (3, 0) ==> (4,-2)     (3, 0)
# Writing:   (5,-2) oL> (3, 0) ==> (5,-2)     (3, 0)
# Writing:   (6,-2) oL> (3, 0) ==> (6,-2)     (3, 0)
# Writing:   (7,-2) oL> (3, 0) ==> (7,-2)     (3, 0)
# Writing:   (0,-2) oL> (4, 0) ==> (0,-2)     (4, 0)
# Writing:   (1,-2) oL> (4, 0) ==> (1,-2)     (4, 0)
# Writing:   (2,-2) oL> (4, 0) ==> (2,-2)     (4, 0)
# Writing:   (3,-2) oL> (4, 0) ==> (3,-2)     (4, 0)
# Writing:   (6,-2) oL> (4, 0) ==> (6,-2)     (4, 0)
# Writing:   (7,-2) oL> (4, 0) ==> (7,-2)     (4, 0)
# Writing:   (0,-2) oL> (5, 0) ==> (0,-2)     (5, 0)
# Writing:   (1,-2) oL> (5, 0) ==> (1,-2)     (5, 0)
# Writing:   (2,-2) oL> (5, 0) ==> (2,-2)     (5, 0)
# Writing:   (3,-2) oL> (5, 0) ==> (3,-2)     (5, 0)
# Writing:   (4,-2) oL> (5, 0) ==> (4,-2)     (5, 0)
# Writing:   (6,-2) oL> (5, 0) ==> (6,-2)     (5, 0)
# Writing:   (7,-2) oL> (5, 0) ==> (7,-2)     (5, 0)
# Writing:   (0,-2) oL> (6, 0) ==> (0,-2)     (6, 0)
# Writing:   (1,-2) oL> (6, 0) ==> (1,-2)     (6, 0)
# Writing:   (2,-2) oL> (6, 0) ==> (2,-2)     (6, 0)
# Writing:   (3,-2) oL> (6, 0) ==> (3,-2)     (6, 0)
# Writing:   (4,-2) oL> (6, 0) ==> (4,-2)     (6, 0)
# Writing:   (5,-2) oL> (6, 0) ==> (5,-2)     (6, 0)
# Writing:   (7,-2) oL> (6, 0) ==> (7,-2)     (6, 0)
# Writing:   (0,-2) oL> (7, 0) ==> (0,-2)     (7, 0)
# Writing:   (1,-2) oL> (7, 0) ==> (1,-2)     (7, 0)
# Writing:   (2,-2) oL> (7, 0) ==> (2,-2)     (7, 0)
# Writing:   (3,-2) oL> (7, 0) ==> (3,-2)     (7, 0)
# Writing:   (4,-2) oL> (7, 0) ==> (4,-2)     (7, 0)
# Writing:   (5,-2) oL> (7, 0) ==> (5,-2)     (7, 0)
# Writing:   (6,-2) oL> (7, 0) ==> (6,-2)     (7, 0)
#
# Test phase complete
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-09'], ['ER-10']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# Orientation phase complete
# p = 1
# Writing:   (1, 0) o?o (7, 0) ==> (1, 0) oLo (7, 0)
# Writing:   (7, 0) o?o (1, 0) ==> (7, 0) oLo (1, 0)
# (1, 0) independent (7, 0) given ((4, 0),) union set()
# (4, 0) independent (7, 0) given ((1, 0),) union set()
# (4, 0) independent (7, 0) given ((5, -2),) union set()
# Writing:   (1, 0) oLo (7, 0) ==> (1, 0)     (7, 0)
# Writing:   (7, 0) oLo (1, 0) ==> (7, 0)     (1, 0)
# Writing:   (4, 0) o?o (7, 0) ==> (4, 0)     (7, 0)
# Writing:   (7, 0) o?o (4, 0) ==> (7, 0)     (4, 0)
# Writing:   (5,-2) oL> (4, 0) ==> (5,-2) o!> (4, 0)
# Writing:   (6,-2) oL> (0, 0) ==> (6,-2) o!> (0, 0)
#
# Test phase complete
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-09'], ['ER-10']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# Orientation phase complete
# p = 2
#
# Test phase complete
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-00-d'], ['ER-00-c'], ['ER-03'], ['R-04'], ['ER-09'], ['ER-10'], ['ER-00-b'], ['ER-00-a']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-00-d:
# Found nothing
#
# ER-00-c:
# Found nothing
#
# ER-03:
# Found nothing
#
# R-04:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# ER-00-b:
# Found nothing
#
# ER-00-a:
# Found nothing
#
# Orientation phase complete
#
# Preliminary phase  1 complete
#
# Graph:
# --------------------------------
# (6,-2) o!> (0, 0)
# (5,-2) o!> (4, 0)
# --------------------------------
#
# =======================================================
# =======================================================
# Starting final ancestral phase
#
# Starting test phase
#
# p = 0
# (0,-2) independent (0, 0) given () union set()
# (0,-1) independent (0, 0) given () union set()
# (1,-2) independent (1, 0) given () union set()
# (1,-1) independent (1, 0) given () union set()
# (2,-2) independent (2, 0) given () union set()
# (2,-1) independent (2, 0) given () union set()
# (3,-2) independent (3, 0) given () union set()
# (3,-1) independent (3, 0) given () union set()
# (4,-2) independent (4, 0) given () union set()
# (4,-1) independent (4, 0) given () union set()
# (5,-2) independent (5, 0) given () union set()
# (5,-1) independent (5, 0) given () union set()
# (6,-2) independent (6, 0) given () union set()
# (6,-1) independent (6, 0) given () union set()
# (7,-2) independent (7, 0) given () union set()
# (7,-1) independent (7, 0) given () union set()
# Writing:   (0,-2) oL> (0, 0) ==> (0,-2)     (0, 0)
# Writing:   (0,-1) oL> (0, 0) ==> (0,-1)     (0, 0)
# Writing:   (1,-2) oL> (1, 0) ==> (1,-2)     (1, 0)
# Writing:   (1,-1) oL> (1, 0) ==> (1,-1)     (1, 0)
# Writing:   (2,-2) oL> (2, 0) ==> (2,-2)     (2, 0)
# Writing:   (2,-1) oL> (2, 0) ==> (2,-1)     (2, 0)
# Writing:   (3,-2) oL> (3, 0) ==> (3,-2)     (3, 0)
# Writing:   (3,-1) oL> (3, 0) ==> (3,-1)     (3, 0)
# Writing:   (4,-2) oL> (4, 0) ==> (4,-2)     (4, 0)
# Writing:   (4,-1) oL> (4, 0) ==> (4,-1)     (4, 0)
# Writing:   (5,-2) oL> (5, 0) ==> (5,-2)     (5, 0)
# Writing:   (5,-1) oL> (5, 0) ==> (5,-1)     (5, 0)
# Writing:   (6,-2) oL> (6, 0) ==> (6,-2)     (6, 0)
# Writing:   (6,-1) oL> (6, 0) ==> (6,-1)     (6, 0)
# Writing:   (7,-2) oL> (7, 0) ==> (7,-2)     (7, 0)
# Writing:   (7,-1) oL> (7, 0) ==> (7,-1)     (7, 0)
# (0, 0) independent (1, 0) given () union set()
# (0, 0) independent (1, 0) given () union set()
# (0, 0) independent (2, 0) given () union set()
# (0, 0) independent (2, 0) given () union set()
# (0, 0) independent (3, 0) given () union set()
# (0, 0) independent (3, 0) given () union set()
# (0, 0) independent (4, 0) given () union set()
# (0, 0) independent (4, 0) given () union set()
# (0, 0) independent (5, 0) given () union set()
# (0, 0) independent (5, 0) given () union set()
# (0, 0) independent (6, 0) given () union set()
# (0, 0) independent (6, 0) given () union set()
# (0, 0) independent (7, 0) given () union set()
# (0, 0) independent (7, 0) given () union set()
# (1, 0) independent (2, 0) given () union set()
# (1, 0) independent (2, 0) given () union set()
# (1, 0) independent (3, 0) given () union set()
# (1, 0) independent (3, 0) given () union set()
# (1, 0) independent (4, 0) given () union set()
# (1, 0) independent (4, 0) given () union set()
# (1, 0) independent (5, 0) given () union set()
# (1, 0) independent (5, 0) given () union set()
# (1, 0) independent (6, 0) given () union set()
# (1, 0) independent (6, 0) given () union set()
# (2, 0) independent (3, 0) given () union set()
# (2, 0) independent (3, 0) given () union set()
# (2, 0) independent (4, 0) given () union set()
# (2, 0) independent (4, 0) given () union set()
# (2, 0) independent (5, 0) given () union set()
# (2, 0) independent (5, 0) given () union set()
# (2, 0) independent (6, 0) given () union set()
# (2, 0) independent (6, 0) given () union set()
# (2, 0) independent (7, 0) given () union set()
# (2, 0) independent (7, 0) given () union set()
# (3, 0) independent (4, 0) given () union set()
# (3, 0) independent (4, 0) given () union set()
# (3, 0) independent (5, 0) given () union set()
# (3, 0) independent (5, 0) given () union set()
# (3, 0) independent (6, 0) given () union set()
# (3, 0) independent (6, 0) given () union set()
# (3, 0) independent (7, 0) given () union set()
# (3, 0) independent (7, 0) given () union set()
# (4, 0) independent (5, 0) given () union set()
# (4, 0) independent (5, 0) given () union set()
# (4, 0) independent (6, 0) given () union set()
# (4, 0) independent (6, 0) given () union set()
# (5, 0) independent (6, 0) given () union set()
# (5, 0) independent (6, 0) given () union set()
# (5, 0) independent (7, 0) given () union set()
# (5, 0) independent (7, 0) given () union set()
# (6, 0) independent (7, 0) given () union set()
# (6, 0) independent (7, 0) given () union set()
# Writing:   (0, 0) o?o (1, 0) ==> (0, 0)     (1, 0)
# Writing:   (1, 0) o?o (0, 0) ==> (1, 0)     (0, 0)
# Writing:   (0, 0) o?o (2, 0) ==> (0, 0)     (2, 0)
# Writing:   (2, 0) o?o (0, 0) ==> (2, 0)     (0, 0)
# Writing:   (1, 0) o?o (2, 0) ==> (1, 0)     (2, 0)
# Writing:   (2, 0) o?o (1, 0) ==> (2, 0)     (1, 0)
# Writing:   (0, 0) o?o (3, 0) ==> (0, 0)     (3, 0)
# Writing:   (3, 0) o?o (0, 0) ==> (3, 0)     (0, 0)
# Writing:   (1, 0) o?o (3, 0) ==> (1, 0)     (3, 0)
# Writing:   (3, 0) o?o (1, 0) ==> (3, 0)     (1, 0)
# Writing:   (2, 0) o?o (3, 0) ==> (2, 0)     (3, 0)
# Writing:   (3, 0) o?o (2, 0) ==> (3, 0)     (2, 0)
# Writing:   (0, 0) o?o (4, 0) ==> (0, 0)     (4, 0)
# Writing:   (4, 0) o?o (0, 0) ==> (4, 0)     (0, 0)
# Writing:   (1, 0) o?o (4, 0) ==> (1, 0)     (4, 0)
# Writing:   (4, 0) o?o (1, 0) ==> (4, 0)     (1, 0)
# Writing:   (2, 0) o?o (4, 0) ==> (2, 0)     (4, 0)
# Writing:   (4, 0) o?o (2, 0) ==> (4, 0)     (2, 0)
# Writing:   (3, 0) o?o (4, 0) ==> (3, 0)     (4, 0)
# Writing:   (4, 0) o?o (3, 0) ==> (4, 0)     (3, 0)
# Writing:   (0, 0) o?o (5, 0) ==> (0, 0)     (5, 0)
# Writing:   (5, 0) o?o (0, 0) ==> (5, 0)     (0, 0)
# Writing:   (1, 0) o?o (5, 0) ==> (1, 0)     (5, 0)
# Writing:   (5, 0) o?o (1, 0) ==> (5, 0)     (1, 0)
# Writing:   (2, 0) o?o (5, 0) ==> (2, 0)     (5, 0)
# Writing:   (5, 0) o?o (2, 0) ==> (5, 0)     (2, 0)
# Writing:   (3, 0) o?o (5, 0) ==> (3, 0)     (5, 0)
# Writing:   (5, 0) o?o (3, 0) ==> (5, 0)     (3, 0)
# Writing:   (4, 0) o?o (5, 0) ==> (4, 0)     (5, 0)
# Writing:   (5, 0) o?o (4, 0) ==> (5, 0)     (4, 0)
# Writing:   (0, 0) o?o (6, 0) ==> (0, 0)     (6, 0)
# Writing:   (6, 0) o?o (0, 0) ==> (6, 0)     (0, 0)
# Writing:   (1, 0) o?o (6, 0) ==> (1, 0)     (6, 0)
# Writing:   (6, 0) o?o (1, 0) ==> (6, 0)     (1, 0)
# Writing:   (2, 0) o?o (6, 0) ==> (2, 0)     (6, 0)
# Writing:   (6, 0) o?o (2, 0) ==> (6, 0)     (2, 0)
# Writing:   (3, 0) o?o (6, 0) ==> (3, 0)     (6, 0)
# Writing:   (6, 0) o?o (3, 0) ==> (6, 0)     (3, 0)
# Writing:   (4, 0) o?o (6, 0) ==> (4, 0)     (6, 0)
# Writing:   (6, 0) o?o (4, 0) ==> (6, 0)     (4, 0)
# Writing:   (5, 0) o?o (6, 0) ==> (5, 0)     (6, 0)
# Writing:   (6, 0) o?o (5, 0) ==> (6, 0)     (5, 0)
# Writing:   (0, 0) o?o (7, 0) ==> (0, 0)     (7, 0)
# Writing:   (7, 0) o?o (0, 0) ==> (7, 0)     (0, 0)
# Writing:   (2, 0) o?o (7, 0) ==> (2, 0)     (7, 0)
# Writing:   (7, 0) o?o (2, 0) ==> (7, 0)     (2, 0)
# Writing:   (3, 0) o?o (7, 0) ==> (3, 0)     (7, 0)
# Writing:   (7, 0) o?o (3, 0) ==> (7, 0)     (3, 0)
# Writing:   (5, 0) o?o (7, 0) ==> (5, 0)     (7, 0)
# Writing:   (7, 0) o?o (5, 0) ==> (7, 0)     (5, 0)
# Writing:   (6, 0) o?o (7, 0) ==> (6, 0)     (7, 0)
# Writing:   (7, 0) o?o (6, 0) ==> (7, 0)     (6, 0)
# (0,-1) independent (1, 0) given () union set()
# (0,-1) independent (2, 0) given () union set()
# (0,-1) independent (3, 0) given () union set()
# (0,-1) independent (4, 0) given () union set()
# (0,-1) independent (5, 0) given () union set()
# (0,-1) independent (6, 0) given () union set()
# (0,-1) independent (7, 0) given () union set()
# (1,-1) independent (0, 0) given () union set()
# (1,-1) independent (2, 0) given () union set()
# (1,-1) independent (3, 0) given () union set()
# (1,-1) independent (4, 0) given () union set()
# (1,-1) independent (5, 0) given () union set()
# (1,-1) independent (6, 0) given () union set()
# (1,-1) independent (7, 0) given () union set()
# (2,-1) independent (0, 0) given () union set()
# (2,-1) independent (1, 0) given () union set()
# (2,-1) independent (3, 0) given () union set()
# (2,-1) independent (4, 0) given () union set()
# (2,-1) independent (5, 0) given () union set()
# (2,-1) independent (6, 0) given () union set()
# (2,-1) independent (7, 0) given () union set()
# (3,-1) independent (0, 0) given () union set()
# (3,-1) independent (1, 0) given () union set()
# (3,-1) independent (2, 0) given () union set()
# (3,-1) independent (4, 0) given () union set()
# (3,-1) independent (5, 0) given () union set()
# (3,-1) independent (6, 0) given () union set()
# (3,-1) independent (7, 0) given () union set()
# (4,-1) independent (0, 0) given () union set()
# (4,-1) independent (1, 0) given () union set()
# (4,-1) independent (2, 0) given () union set()
# (4,-1) independent (3, 0) given () union set()
# (4,-1) independent (5, 0) given () union set()
# (4,-1) independent (6, 0) given () union set()
# (4,-1) independent (7, 0) given () union set()
# (5,-1) independent (0, 0) given () union set()
# (5,-1) independent (1, 0) given () union set()
# (5,-1) independent (2, 0) given () union set()
# (5,-1) independent (3, 0) given () union set()
# (5,-1) independent (4, 0) given () union set()
# (5,-1) independent (6, 0) given () union set()
# (5,-1) independent (7, 0) given () union set()
# (6,-1) independent (0, 0) given () union set()
# (6,-1) independent (1, 0) given () union set()
# (6,-1) independent (2, 0) given () union set()
# (6,-1) independent (3, 0) given () union set()
# (6,-1) independent (4, 0) given () union set()
# (6,-1) independent (5, 0) given () union set()
# (6,-1) independent (7, 0) given () union set()
# (7,-1) independent (0, 0) given () union set()
# (7,-1) independent (1, 0) given () union set()
# (7,-1) independent (2, 0) given () union set()
# (7,-1) independent (3, 0) given () union set()
# (7,-1) independent (4, 0) given () union set()
# (7,-1) independent (5, 0) given () union set()
# (7,-1) independent (6, 0) given () union set()
# Writing:   (1,-1) oL> (0, 0) ==> (1,-1)     (0, 0)
# Writing:   (2,-1) oL> (0, 0) ==> (2,-1)     (0, 0)
# Writing:   (3,-1) oL> (0, 0) ==> (3,-1)     (0, 0)
# Writing:   (4,-1) oL> (0, 0) ==> (4,-1)     (0, 0)
# Writing:   (5,-1) oL> (0, 0) ==> (5,-1)     (0, 0)
# Writing:   (6,-1) oL> (0, 0) ==> (6,-1)     (0, 0)
# Writing:   (7,-1) oL> (0, 0) ==> (7,-1)     (0, 0)
# Writing:   (0,-1) oL> (1, 0) ==> (0,-1)     (1, 0)
# Writing:   (2,-1) oL> (1, 0) ==> (2,-1)     (1, 0)
# Writing:   (3,-1) oL> (1, 0) ==> (3,-1)     (1, 0)
# Writing:   (4,-1) oL> (1, 0) ==> (4,-1)     (1, 0)
# Writing:   (5,-1) oL> (1, 0) ==> (5,-1)     (1, 0)
# Writing:   (6,-1) oL> (1, 0) ==> (6,-1)     (1, 0)
# Writing:   (7,-1) oL> (1, 0) ==> (7,-1)     (1, 0)
# Writing:   (0,-1) oL> (2, 0) ==> (0,-1)     (2, 0)
# Writing:   (1,-1) oL> (2, 0) ==> (1,-1)     (2, 0)
# Writing:   (3,-1) oL> (2, 0) ==> (3,-1)     (2, 0)
# Writing:   (4,-1) oL> (2, 0) ==> (4,-1)     (2, 0)
# Writing:   (5,-1) oL> (2, 0) ==> (5,-1)     (2, 0)
# Writing:   (6,-1) oL> (2, 0) ==> (6,-1)     (2, 0)
# Writing:   (7,-1) oL> (2, 0) ==> (7,-1)     (2, 0)
# Writing:   (0,-1) oL> (3, 0) ==> (0,-1)     (3, 0)
# Writing:   (1,-1) oL> (3, 0) ==> (1,-1)     (3, 0)
# Writing:   (2,-1) oL> (3, 0) ==> (2,-1)     (3, 0)
# Writing:   (4,-1) oL> (3, 0) ==> (4,-1)     (3, 0)
# Writing:   (5,-1) oL> (3, 0) ==> (5,-1)     (3, 0)
# Writing:   (6,-1) oL> (3, 0) ==> (6,-1)     (3, 0)
# Writing:   (7,-1) oL> (3, 0) ==> (7,-1)     (3, 0)
# Writing:   (0,-1) oL> (4, 0) ==> (0,-1)     (4, 0)
# Writing:   (1,-1) oL> (4, 0) ==> (1,-1)     (4, 0)
# Writing:   (2,-1) oL> (4, 0) ==> (2,-1)     (4, 0)
# Writing:   (3,-1) oL> (4, 0) ==> (3,-1)     (4, 0)
# Writing:   (5,-1) oL> (4, 0) ==> (5,-1)     (4, 0)
# Writing:   (6,-1) oL> (4, 0) ==> (6,-1)     (4, 0)
# Writing:   (7,-1) oL> (4, 0) ==> (7,-1)     (4, 0)
# Writing:   (0,-1) oL> (5, 0) ==> (0,-1)     (5, 0)
# Writing:   (1,-1) oL> (5, 0) ==> (1,-1)     (5, 0)
# Writing:   (2,-1) oL> (5, 0) ==> (2,-1)     (5, 0)
# Writing:   (3,-1) oL> (5, 0) ==> (3,-1)     (5, 0)
# Writing:   (4,-1) oL> (5, 0) ==> (4,-1)     (5, 0)
# Writing:   (6,-1) oL> (5, 0) ==> (6,-1)     (5, 0)
# Writing:   (7,-1) oL> (5, 0) ==> (7,-1)     (5, 0)
# Writing:   (0,-1) oL> (6, 0) ==> (0,-1)     (6, 0)
# Writing:   (1,-1) oL> (6, 0) ==> (1,-1)     (6, 0)
# Writing:   (2,-1) oL> (6, 0) ==> (2,-1)     (6, 0)
# Writing:   (3,-1) oL> (6, 0) ==> (3,-1)     (6, 0)
# Writing:   (4,-1) oL> (6, 0) ==> (4,-1)     (6, 0)
# Writing:   (5,-1) oL> (6, 0) ==> (5,-1)     (6, 0)
# Writing:   (7,-1) oL> (6, 0) ==> (7,-1)     (6, 0)
# Writing:   (0,-1) oL> (7, 0) ==> (0,-1)     (7, 0)
# Writing:   (1,-1) oL> (7, 0) ==> (1,-1)     (7, 0)
# Writing:   (2,-1) oL> (7, 0) ==> (2,-1)     (7, 0)
# Writing:   (3,-1) oL> (7, 0) ==> (3,-1)     (7, 0)
# Writing:   (4,-1) oL> (7, 0) ==> (4,-1)     (7, 0)
# Writing:   (5,-1) oL> (7, 0) ==> (5,-1)     (7, 0)
# Writing:   (6,-1) oL> (7, 0) ==> (6,-1)     (7, 0)
# (0,-2) independent (1, 0) given () union set()
# (0,-2) independent (2, 0) given () union set()
# (0,-2) independent (3, 0) given () union set()
# (0,-2) independent (4, 0) given () union set()
# (0,-2) independent (5, 0) given () union set()
# (0,-2) independent (6, 0) given () union set()
# (0,-2) independent (7, 0) given () union set()
# (1,-2) independent (0, 0) given () union set()
# (1,-2) independent (2, 0) given () union set()
# (1,-2) independent (3, 0) given () union set()
# (1,-2) independent (4, 0) given () union set()
# (1,-2) independent (5, 0) given () union set()
# (1,-2) independent (6, 0) given () union set()
# (1,-2) independent (7, 0) given () union set()
# (2,-2) independent (0, 0) given () union set()
# (2,-2) independent (1, 0) given () union set()
# (2,-2) independent (3, 0) given () union set()
# (2,-2) independent (4, 0) given () union set()
# (2,-2) independent (5, 0) given () union set()
# (2,-2) independent (6, 0) given () union set()
# (2,-2) independent (7, 0) given () union set()
# (3,-2) independent (0, 0) given () union set()
# (3,-2) independent (1, 0) given () union set()
# (3,-2) independent (2, 0) given () union set()
# (3,-2) independent (4, 0) given () union set()
# (3,-2) independent (5, 0) given () union set()
# (3,-2) independent (6, 0) given () union set()
# (3,-2) independent (7, 0) given () union set()
# (4,-2) independent (0, 0) given () union set()
# (4,-2) independent (1, 0) given () union set()
# (4,-2) independent (2, 0) given () union set()
# (4,-2) independent (3, 0) given () union set()
# (4,-2) independent (5, 0) given () union set()
# (4,-2) independent (6, 0) given () union set()
# (4,-2) independent (7, 0) given () union set()
# (5,-2) independent (0, 0) given () union set()
# (5,-2) independent (1, 0) given () union set()
# (5,-2) independent (2, 0) given () union set()
# (5,-2) independent (3, 0) given () union set()
# (5,-2) independent (6, 0) given () union set()
# (5,-2) independent (7, 0) given () union set()
# (6,-2) independent (1, 0) given () union set()
# (6,-2) independent (2, 0) given () union set()
# (6,-2) independent (3, 0) given () union set()
# (6,-2) independent (4, 0) given () union set()
# (6,-2) independent (5, 0) given () union set()
# (6,-2) independent (7, 0) given () union set()
# (7,-2) independent (0, 0) given () union set()
# (7,-2) independent (1, 0) given () union set()
# (7,-2) independent (2, 0) given () union set()
# (7,-2) independent (3, 0) given () union set()
# (7,-2) independent (4, 0) given () union set()
# (7,-2) independent (5, 0) given () union set()
# (7,-2) independent (6, 0) given () union set()
# Writing:   (1,-2) oL> (0, 0) ==> (1,-2)     (0, 0)
# Writing:   (2,-2) oL> (0, 0) ==> (2,-2)     (0, 0)
# Writing:   (3,-2) oL> (0, 0) ==> (3,-2)     (0, 0)
# Writing:   (4,-2) oL> (0, 0) ==> (4,-2)     (0, 0)
# Writing:   (5,-2) oL> (0, 0) ==> (5,-2)     (0, 0)
# Writing:   (7,-2) oL> (0, 0) ==> (7,-2)     (0, 0)
# Writing:   (0,-2) oL> (1, 0) ==> (0,-2)     (1, 0)
# Writing:   (2,-2) oL> (1, 0) ==> (2,-2)     (1, 0)
# Writing:   (3,-2) oL> (1, 0) ==> (3,-2)     (1, 0)
# Writing:   (4,-2) oL> (1, 0) ==> (4,-2)     (1, 0)
# Writing:   (5,-2) oL> (1, 0) ==> (5,-2)     (1, 0)
# Writing:   (6,-2) oL> (1, 0) ==> (6,-2)     (1, 0)
# Writing:   (7,-2) oL> (1, 0) ==> (7,-2)     (1, 0)
# Writing:   (0,-2) oL> (2, 0) ==> (0,-2)     (2, 0)
# Writing:   (1,-2) oL> (2, 0) ==> (1,-2)     (2, 0)
# Writing:   (3,-2) oL> (2, 0) ==> (3,-2)     (2, 0)
# Writing:   (4,-2) oL> (2, 0) ==> (4,-2)     (2, 0)
# Writing:   (5,-2) oL> (2, 0) ==> (5,-2)     (2, 0)
# Writing:   (6,-2) oL> (2, 0) ==> (6,-2)     (2, 0)
# Writing:   (7,-2) oL> (2, 0) ==> (7,-2)     (2, 0)
# Writing:   (0,-2) oL> (3, 0) ==> (0,-2)     (3, 0)
# Writing:   (1,-2) oL> (3, 0) ==> (1,-2)     (3, 0)
# Writing:   (2,-2) oL> (3, 0) ==> (2,-2)     (3, 0)
# Writing:   (4,-2) oL> (3, 0) ==> (4,-2)     (3, 0)
# Writing:   (5,-2) oL> (3, 0) ==> (5,-2)     (3, 0)
# Writing:   (6,-2) oL> (3, 0) ==> (6,-2)     (3, 0)
# Writing:   (7,-2) oL> (3, 0) ==> (7,-2)     (3, 0)
# Writing:   (0,-2) oL> (4, 0) ==> (0,-2)     (4, 0)
# Writing:   (1,-2) oL> (4, 0) ==> (1,-2)     (4, 0)
# Writing:   (2,-2) oL> (4, 0) ==> (2,-2)     (4, 0)
# Writing:   (3,-2) oL> (4, 0) ==> (3,-2)     (4, 0)
# Writing:   (6,-2) oL> (4, 0) ==> (6,-2)     (4, 0)
# Writing:   (7,-2) oL> (4, 0) ==> (7,-2)     (4, 0)
# Writing:   (0,-2) oL> (5, 0) ==> (0,-2)     (5, 0)
# Writing:   (1,-2) oL> (5, 0) ==> (1,-2)     (5, 0)
# Writing:   (2,-2) oL> (5, 0) ==> (2,-2)     (5, 0)
# Writing:   (3,-2) oL> (5, 0) ==> (3,-2)     (5, 0)
# Writing:   (4,-2) oL> (5, 0) ==> (4,-2)     (5, 0)
# Writing:   (6,-2) oL> (5, 0) ==> (6,-2)     (5, 0)
# Writing:   (7,-2) oL> (5, 0) ==> (7,-2)     (5, 0)
# Writing:   (0,-2) oL> (6, 0) ==> (0,-2)     (6, 0)
# Writing:   (1,-2) oL> (6, 0) ==> (1,-2)     (6, 0)
# Writing:   (2,-2) oL> (6, 0) ==> (2,-2)     (6, 0)
# Writing:   (3,-2) oL> (6, 0) ==> (3,-2)     (6, 0)
# Writing:   (4,-2) oL> (6, 0) ==> (4,-2)     (6, 0)
# Writing:   (5,-2) oL> (6, 0) ==> (5,-2)     (6, 0)
# Writing:   (7,-2) oL> (6, 0) ==> (7,-2)     (6, 0)
# Writing:   (0,-2) oL> (7, 0) ==> (0,-2)     (7, 0)
# Writing:   (1,-2) oL> (7, 0) ==> (1,-2)     (7, 0)
# Writing:   (2,-2) oL> (7, 0) ==> (2,-2)     (7, 0)
# Writing:   (3,-2) oL> (7, 0) ==> (3,-2)     (7, 0)
# Writing:   (4,-2) oL> (7, 0) ==> (4,-2)     (7, 0)
# Writing:   (5,-2) oL> (7, 0) ==> (5,-2)     (7, 0)
# Writing:   (6,-2) oL> (7, 0) ==> (6,-2)     (7, 0)
#
# Test phase complete
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-09'], ['ER-10']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# Orientation phase complete
# p = 1
# Writing:   (1, 0) o?o (7, 0) ==> (1, 0) oLo (7, 0)
# Writing:   (7, 0) o?o (1, 0) ==> (7, 0) oLo (1, 0)
# (1, 0) independent (7, 0) given ((4, 0),) union set()
# (4, 0) independent (7, 0) given ((1, 0),) union set()
# (4, 0) independent (7, 0) given ((5, -2),) union set()
# Writing:   (1, 0) oLo (7, 0) ==> (1, 0)     (7, 0)
# Writing:   (7, 0) oLo (1, 0) ==> (7, 0)     (1, 0)
# Writing:   (4, 0) o?o (7, 0) ==> (4, 0)     (7, 0)
# Writing:   (7, 0) o?o (4, 0) ==> (7, 0)     (4, 0)
# Writing:   (5,-2) oL> (4, 0) ==> (5,-2) o!> (4, 0)
# Writing:   (6,-2) oL> (0, 0) ==> (6,-2) o!> (0, 0)
#
# Test phase complete
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-09'], ['ER-10']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# Orientation phase complete
# p = 2
#
# Test phase complete
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-00-d'], ['ER-00-c'], ['ER-03'], ['R-04'], ['ER-09'], ['ER-10'], ['ER-00-b'], ['ER-00-a']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-00-d:
# Found nothing
#
# ER-00-c:
# Found nothing
#
# ER-03:
# Found nothing
#
# R-04:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# ER-00-b:
# Found nothing
#
# ER-00-a:
# Found nothing
#
# Orientation phase complete
#
# Final ancestral phase complete
#
# Graph:
# --------------------------------
# (6,-2) o!> (0, 0)
# (5,-2) o!> (4, 0)
# --------------------------------
#
# =======================================================
# =======================================================
# Starting non-ancestral phase
#
# Middle mark updates
#
#
# Starting test phase
#
# p = 0
#
# Test phase complete
# p = 1
# Writing:   (5,-2) o!> (4, 0) ==> (5,-2) o-> (4, 0)
# Writing:   (6,-2) o!> (0, 0) ==> (6,-2) o-> (0, 0)
#
# Test phase complete
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-00-d'], ['ER-00-c'], ['ER-03'], ['R-04'], ['ER-09'], ['ER-10'], ['ER-00-b'], ['ER-00-a']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-00-d:
# Found nothing
#
# ER-00-c:
# Found nothing
#
# ER-03:
# Found nothing
#
# R-04:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# ER-00-b:
# Found nothing
#
# ER-00-a:
# Found nothing
#
# Orientation phase complete
#
# Non-ancestral phase complete
#
# Graph:
# --------------------------------
# (6,-2) o-> (0, 0)
# (5,-2) o-> (4, 0)
# --------------------------------
#
# =======================================================
# =======================================================
# Final rule application phase
#
# Setting all middle marks to '-'
#
# Starting orientation phase
# with rule list:  [['APR'], ['ER-08'], ['ER-02'], ['ER-01'], ['ER-00-d'], ['ER-00-c'], ['ER-03'], ['R-04'], ['ER-09'], ['ER-10'], ['ER-00-b'], ['ER-00-a']]
#
# APR:
# Found nothing
#
# ER-08:
# Found nothing
#
# ER-02:
# Found nothing
#
# ER-01:
# Found nothing
#
# ER-00-d:
# Found nothing
#
# ER-00-c:
# Found nothing
#
# ER-03:
# Found nothing
#
# R-04:
# Found nothing
#
# ER-09:
# Found nothing
#
# ER-10:
# Found nothing
#
# ER-00-b:
# Found nothing
#
# ER-00-a:
# Found nothing
#
# Orientation phase complete
#
# =======================================================
# =======================================================
#
# LPCMCI has converged
#
# Final graph:
# --------------------------------
# --------------------------------
# (6,-2) o-> (0, 0)
# (5,-2) o-> (4, 0)
# --------------------------------
# --------------------------------
#
# Max search set: 0
# Max na-pds set: 0
# '\ngraph : array of shape (N, N, tau_max+1)\n            Resulting DPAG, representing the learned causal relationships.\n        val_matrix : array of shape (N, N, tau_max+1)\n            Estimated matrix of test statistic values regarding adjacencies.\n        p_matrix : array of shape [N, N, tau_max+1]\n            Estimated matrix of p-values regarding adjacencies.\n'

# %%
print(results['val_matrix'])
# Out:
# [[[ 0.00000000e+00  1.11789491e-02  2.10604930e-02]
#   [ 4.30110253e-02  1.70340091e-02  1.95334244e-02]
#   [ 2.98117263e-02  3.54338255e-03  6.84784478e-03]
#   [ 6.37321268e-03  1.58393197e-02  4.61359130e-03]
#   [ 1.07973159e-02  2.50071939e-02  4.22645159e-02]
#   [ 2.54543579e-02  1.43126312e-02  4.35348140e-03]
#   [ 1.97886048e-02  1.42323623e-02  1.99759693e-02]
#   [ 1.52517705e-02  2.38207317e-02  1.51004749e-02]]
#
#  [[ 4.30110253e-02  1.07226439e-02  2.03433657e-03]
#   [ 0.00000000e+00  8.87772776e-03  3.60721608e-02]
#   [ 4.50257836e-02  4.83568021e-03  1.05703944e-02]
#   [ 2.84559006e-02  3.82704203e-02 -3.86246864e-04]
#   [ 4.16383190e-02  2.26736401e-02  3.84101693e-02]
#   [ 6.39391455e-03  9.83841348e-03 -2.71606486e-03]
#   [ 3.73180262e-02  4.93593229e-02  7.65171633e-03]
#   [ 1.95071790e-02  5.87761185e-03  7.89487530e-04]]
#
#  [[ 2.98117263e-02  1.80583524e-02  8.42928842e-03]
#   [ 4.50257836e-02  2.16310849e-02  3.29855342e-02]
#   [ 0.00000000e+00  2.66851465e-02  3.95477469e-03]
#   [ 1.02841204e-02  2.33728821e-02  1.25582550e-02]
#   [ 2.95546232e-03 -4.82213752e-03  2.58850005e-02]
#   [ 1.18121963e-02 -1.26331918e-02  2.41929734e-03]
#   [ 3.44156372e-02  2.33101783e-02 -8.44631862e-03]
#   [ 1.96002017e-02  1.47086189e-02 -3.16869239e-03]]
#
#  [[ 6.37321268e-03  7.51065196e-03  1.78983819e-02]
#   [ 2.84559006e-02  6.92320831e-03  2.32823622e-02]
#   [ 1.02841204e-02  2.22872755e-02  3.36578706e-02]
#   [ 0.00000000e+00  2.92951788e-02  6.49763893e-03]
#   [ 1.13179392e-02  6.93131879e-04  6.60662620e-03]
#   [ 1.93858445e-02  1.80437898e-02  1.15244484e-02]
#   [ 3.93659289e-02 -4.97659134e-03  1.12514941e-02]
#   [ 3.91970000e-02  7.31704573e-03  1.87619082e-02]]
#
#  [[ 1.07973159e-02  7.31419265e-03  2.29256689e-03]
#   [ 4.16383190e-02  1.05781568e-02  1.67126058e-02]
#   [ 2.95546232e-03 -4.99486149e-03  2.11810765e-02]
#   [ 1.13179392e-02  2.60331859e-02 -2.80895939e-03]
#   [ 0.00000000e+00  2.35430192e-02  1.57023987e-02]
#   [ 1.32316202e-02  3.05934217e-02  2.08710532e-02]
#   [ 1.16900338e-02  1.00380719e-02  5.01288228e-04]
#   [ 3.44520478e-02  1.41991755e-02 -3.30528317e-05]]
#
#  [[ 2.54543579e-02 -3.90779053e-03  8.57986072e-03]
#   [ 6.39391455e-03  1.13342791e-02  1.32590393e-02]
#   [ 1.18121963e-02  1.26472081e-02  8.11764478e-03]
#   [ 1.93858445e-02  2.24120877e-02  2.21782207e-02]
#   [ 1.32316202e-02  7.73439997e-03  8.85052691e-02]
#   [ 0.00000000e+00  2.11380757e-02  1.88447995e-02]
#   [ 2.29520064e-02  3.43425085e-02 -2.40798494e-03]
#   [ 1.22632242e-02  2.53876478e-03  5.66336821e-03]]
#
#  [[ 1.97886048e-02  7.27619157e-03  6.13897346e-02]
#   [ 3.73180262e-02  1.18664472e-02  1.47570728e-02]
#   [ 3.44156372e-02  6.19156406e-03  1.54354291e-03]
#   [ 3.93659289e-02  1.22780286e-02  5.22806226e-03]
#   [ 1.16900338e-02 -2.62227782e-04  6.24914332e-03]
#   [ 2.29520064e-02  3.17059564e-03  4.41266639e-02]
#   [ 0.00000000e+00  3.80162112e-02  1.82984494e-02]
#   [ 4.46622605e-02  1.06690418e-02  3.02392979e-03]]
#
#  [[ 1.52517705e-02  1.81424156e-02  3.73665228e-02]
#   [ 1.95071790e-02  1.86341130e-02  1.95943739e-02]
#   [ 1.96002017e-02  1.29624847e-02  5.27729891e-03]
#   [ 3.91970000e-02  3.90337774e-02  8.09859825e-03]
#   [ 3.44520478e-02  7.37517680e-03  8.64236333e-03]
#   [ 1.22632242e-02  1.68826772e-02  2.77041338e-02]
#   [ 4.46622605e-02  1.19345024e-02 -1.20023528e-03]
#   [ 0.00000000e+00  1.95459262e-02  1.06790513e-02]]]

# %%
#cmi_knn = CMIknn(significance='fixed_thres', model_selection_folds=3)
#cmi_knn = CMIknn(significance='shuffle_test', knn=0.1, shuffle_neighbors=5, transform='ranks', sig_samples=200)
rcot_test = RCOT(seed=42)
lpcmci_loc = LPCMCI(
    dataframe=dataframe, 
    cond_ind_test=rcot_test,
    verbosity=1)
results = lpcmci_loc.run_lpcmci(tau_max=2, pc_alpha=.05, link_assumptions = link_assumptions)
tp.plot_time_series_graph(graph=results['graph'],
                          val_matrix=results['val_matrix'], save_name = "cmiknn_simulated_linkass.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #cmi_knn = CMIknn(significance='fixed_thres', model_selection_folds=3)
#       2 #cmi_knn = CMIknn(significance='shuffle_test', knn=0.1, shuffle_neighbors=5, transform='ranks', sig_samples=200)
# ----> 3 rcot_test = RCOT(seed=42)
#       4 lpcmci_loc = LPCMCI(
#       5     dataframe=dataframe,
#       6     cond_ind_test=rcot_test,
#       7     verbosity=1)
#       8 results = lpcmci_loc.run_lpcmci(tau_max=2, pc_alpha=.05, link_assumptions = link_assumptions)
#
# NameError: name 'RCOT' is not defined

# %%
print(results['val_matrix'])
# Out:
# [[[ 0.          0.00276912        -inf]
#   [-0.00144616  0.00849052        -inf]
#   [-0.00537789        -inf        -inf]
#   [-0.00063752        -inf        -inf]
#   [-0.00529904        -inf        -inf]
#   [ 0.00306448        -inf        -inf]
#   [-0.00542751        -inf        -inf]
#   [       -inf  0.01402099        -inf]]
#
#  [[-0.00144616  0.01071751        -inf]
#   [ 0.                -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.00066662  0.00587496        -inf]]
#
#  [[-0.00537789        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.                -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.00642137        -inf        -inf]]
#
#  [[-0.00063752        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.                -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.00961522        -inf        -inf]]
#
#  [[-0.00529904        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.                -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.01429011        -inf        -inf]]
#
#  [[ 0.00306448        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.                -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.00565426        -inf        -inf]]
#
#  [[-0.00542751        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [       -inf        -inf        -inf]
#   [ 0.                -inf        -inf]
#   [ 0.01423602        -inf        -inf]]
#
#  [[       -inf        -inf        -inf]
#   [ 0.00066662  0.01999669        -inf]
#   [ 0.00642137        -inf        -inf]
#   [ 0.00961522        -inf        -inf]
#   [ 0.01429011        -inf        -inf]
#   [ 0.00565426        -inf        -inf]
#   [ 0.01423602        -inf        -inf]
#   [ 0.          0.00291552        -inf]]]
